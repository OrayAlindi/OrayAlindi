# %% [markdown]
# <a href="https://colab.research.google.com/github/OrayAlindi/OrayAlindi/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
In [ ]:
# Out:
#   File "/tmp/ipython-input-1547241538.py", line 1
#     In [ ]:
#          ^
# SyntaxError: invalid syntax

# %%
# Comments start with "#"
# You can print text or calculations

print("Welcome to my Python journey!")
print("2 + 3 =", 2 + 3)
print("10 divided by 2 =", 10 / 2)
# Out:
# Welcome to my Python journey!
# 2 + 3 = 5
# 10 divided by 2 = 5.0

# %%
print("My name is Godfrey Alindi, I am learning Python in order to implement data analysis on Mobile data and Humanaitarian Efforts")
# Out:
# My name is Godfrey Alindi, I am learning Python in order to implement data analysis on Mobile data and Humanaitarian Efforts

# %%
print("Today is October 14, 2025")
# Out:
# Today is October 14, 2025

# %%
print("5*8", 5*8)
# Out:
# 5*8 40

# %%
print(5 * 8)
# Out:
# 40

# %%
print(3 + 4 * 2)
# Out:
# 11

# %%
# My introduction program
print("My name is Godfrey Alindi.")
print("I'm learning Python to work with mobile and humanitarian data.")
# Out:
# My name is Godfrey Alindi.
# I'm learning Python to work with mobile and humanitarian data.

# %%
print("Python" + " " + "Rocks!")
# Out:
# Python Rocks!

# %%
print(8 / 2 + 3 * 2)
# Out:
# 10.0

# %%
if True:
    print("Hello!")
# Out:
# Hello!

# %%
print("2 + 3 =", 2 + 3)
# Out:
# 2 + 3 = 5

# %%
print(f"2 + 3 = {2 + 3}")
# Out:
# 2 + 3 = 5
